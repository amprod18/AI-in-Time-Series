# %% [markdown]
# # Libraries

# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append('../')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from AI_in_Time_Series import SampleODEs
from AI_in_Time_Series.data import create_synthetic_dataset
from AI_in_Time_Series.visualization import print_datasetstorer_hierarchy, visualize_tree

# %%
from torch import Tensor

# %%
# Create a Damped Oscillator dataset as an example
ds_parameters = {'ode_func':SampleODEs.damped_oscillator, 'start_t':0., 'max_t':25., 'n_points':2000, 'look_ahead':1, 'initial_guess':Tensor([-1., 0.]), 'method':'rk4', 'ode_params':{'mass':1, 'damping':0.2, 'stiffness':1}}
ds_dataset = create_synthetic_dataset(ds_parameters, display_heads=True, plot_result=True)
# Out:
# (1600, 3) (1600, 2) (400, 3) (400, 2) (1600, 3) (1600, 2) (400, 3) (400, 2)
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>t</th>
#       <th>Component1</th>
#       <th>Component2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1595</th>
#       <td>0.997498</td>
#       <td>0.528338</td>
#       <td>0.498326</td>
#     </tr>
#     <tr>
#       <th>1596</th>
#       <td>0.998124</td>
#       <td>0.529167</td>
#       <td>0.498851</td>
#     </tr>
#     <tr>
#       <th>1597</th>
#       <td>0.998749</td>
#       <td>0.530002</td>
#       <td>0.499364</td>
#     </tr>
#     <tr>
#       <th>1598</th>
#       <td>0.999375</td>
#       <td>0.530842</td>
#       <td>0.499862</td>
#     </tr>
#     <tr>
#       <th>1599</th>
#       <td>1.000000</td>
#       <td>0.531687</td>
#       <td>0.500348</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
# ...

# %%
# Now the dataset has containers
print_datasetstorer_hierarchy(ds_dataset)
# Out:
# - main
#   - data
#     - X_test
#     - X_test_scaled
#     - X_train
#     - X_train_scaled
#     - y_test
#     - y_test_scaled
#     - y_train
#     - y_train_scaled
#   - features
#   - initial_guess
#   - look_ahead
#   - max_t
#   - method
#   - n_points
#   - ode_params
#   - scalers
#     - sc_x
#     - sc_y
#   - start_t
#   - targets
#   - train_size
# {'main': {'data': {'X_test': None,
#    'X_test_scaled': None,
#    'X_train': None,
#    'X_train_scaled': None,
#    'y_test': None,
#    'y_test_scaled': None,
#    'y_train': None,
#    'y_train_scaled': None},
#   'features': None,
#   'initial_guess': None,
#   'look_ahead': None,
#   'max_t': None,
#   'method': None,
#   'n_points': None,
#   'ode_params': None,
#   'scalers': {'sc_x': None, 'sc_y': None},
#   'start_t': None,
#   'targets': None,
#   'train_size': None}}

# %%
# Or in a graph form
visualize_tree(ds_dataset, use_pydot=True)

# %%
# Containers can be accessed as class attributes
visualize_tree(ds_dataset.data, use_pydot=True)
visualize_tree(ds_dataset.scalers, use_pydot=True)

# %%
# And also every parameter they got inside
ds_dataset.data.X_train
# Out:
#               t  Component1  Component2
# 0      0.000000   -1.000000    0.000000
# 1      0.012500   -0.999922    0.012484
# 2      0.025000   -0.999688    0.024935
# 3      0.037500   -0.999299    0.037351
# 4      0.050000   -0.998754    0.049730
# ...         ...         ...         ...
# 1595  19.937500   -0.086377    0.114277
# 1596  19.949999   -0.084944    0.115061
# 1597  19.962500   -0.083501    0.115825
# 1598  19.975000   -0.082048    0.116569
# 1599  19.987499   -0.080587    0.117293
#
# [1600 rows x 3 columns]
